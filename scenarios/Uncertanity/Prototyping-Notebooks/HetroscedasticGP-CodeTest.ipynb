# %%
import GPy
import copy
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (12,7)
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['lines.linewidth'] = 4.0
plt.rcParams['font.size'] = 18.0
plt.rcParams['font.sans-serif'] = 'Helvetica'

# %%
x  = np.linspace(0, 1, 100)
fx = 4.0*np.sin(2.0*np.pi*x)

y = np.zeros(len(x))
for idx,i in enumerate(x):
    y[idx] = 4.0*np.sin(2.0*np.pi*i) + np.random.normal(0.0, i+0.0)

plt.plot(x, fx, label="True Signal")
plt.plot(x, y, 'o', label="Noisy Observations")
plt.title("Synthetic Data")
plt.legend()

# %% [markdown]
# # Gaussian Processes GPy

# %%
# RBF and WhiteNoise kernel
kernel1 = GPy.kern.RBF(input_dim=1) + GPy.kern.White(input_dim=1)
gp1 = GPy.models.GPRegression(x.reshape(-1,1),y.reshape(-1,1),kernel1)
gp1.optimize(messages=False)
gp1.optimize_restarts(num_restarts = 5)

var_pref = np.zeros((x.shape[0],1))

eps = np.inf
iterations = 0
while ~(eps <= 0.01 or iterations > 10):
    
    m, v = gp1.predict(x.reshape(-1,1))
    s = 10
    variance_noise = np.zeros(len(x))
    for j in range(0, len(x)):
        var = 0.0
        for i in range(0, s):
            var += 0.5 * (y[j] - np.random.normal(m[j], v[j]))**2
        variance_noise[j] = var/s
    z = np.log(variance_noise)

    kernel2 = GPy.kern.RBF(input_dim=1) + GPy.kern.White(input_dim=1)
    gp2 = GPy.models.GPRegression(x.reshape(-1,1),z.reshape(-1,1),kernel2)
    gp2.optimize(messages=False)
    gp2.optimize_restarts(num_restarts = 5)
    m_n, v_n = gp2.predict(x.reshape(-1,1))

    kernel3 = GPy.kern.RBF(input_dim=1) + GPy.kern.WhiteHeteroscedastic(input_dim=1, num_data=x.shape[0])
    gp3 = GPy.models.GPRegression(x.reshape(-1,1),y.reshape(-1,1),kernel3)
    gp3.optimize(messages=False)
    gp3.optimize_restarts(num_restarts = 10)
    kernel3.parts[1].variance = np.exp(m_n).reshape(x.shape[0])

    m, v = gp3.predict(x.reshape(-1,1))
    
    diff = var_pref - v
    eps = np.dot(diff.T, diff)[0][0]
    gp1 = copy.deepcopy(gp3)
    var_pref = copy.deepcopy(v)
    print(eps)
    iterations += 1
# Out:
# Optimization restart 1/5, f = 98.55315228024804
# Optimization restart 2/5, f = 98.5531522805165
# Optimization restart 3/5, f = 98.55315228024708
# Optimization restart 4/5, f = 98.55315228025191
# Optimization restart 5/5, f = 98.55315228024604
# Optimization restart 1/5, f = 133.98269768994788
# Optimization restart 2/5, f = 133.98269769277226
# Optimization restart 3/5, f = 133.98269769574352
# Optimization restart 4/5, f = 133.98269769042577
# Optimization restart 5/5, f = 133.98269769649997
# Optimization restart 1/10, f = -31.162160337148563
# Optimization restart 2/10, f = -27.855576484713502
# Optimization restart 3/10, f = -27.395883941635283
# Optimization restart 4/10, f = -36.37789521234926
# Optimization restart 5/10, f = -27.308851094040698
# Optimization restart 6/10, f = -34.735844910077155
# Optimization restart 7/10, f = -25.39959765874309
# Optimization restart 8/10, f = -30.220978390071103
# Optimization restart 9/10, f = -31.16210279501844
# Optimization restart 10/10, f = -34.73561984980893
# 2.493587561894228
# Optimization restart 1/5, f = 168.36967585439385
# Optimization restart 2/5, f = 168.36967585567425
# Optimization restart 3/5, f = 168.3696758546772
# Optimization restart 4/5, f = 168.369676133843
# Optimization restart 5/5, f = 168.36967585493824
# Optimization restart 1/10, f = -31.162160337148563
# Optimization restart 2/10, f = -30.525286997774266
# Optimization restart 3/10, f = -27.72105553996296
# Optimization restart 4/10, f = -27.459309114935074
# Optimization restart 5/10, f = -28.378416917381017
# Optimization restart 6/10, f = -43.41908957195534
# Optimization restart 7/10, f = -41.67714148676037
# Optimization restart 8/10, f = -33.47264388694284
# Optimization restart 9/10, f = -34.69888209817882
# Optimization restart 10/10, f = -28.722747465699584
# 0.3986316027524791
# Optimization restart 1/5, f = 210.4570745642045
# Optimization restart 2/5, f = 210.45707456416582
# Optimization restart 3/5, f = 210.45707456418802
# Optimization restart 4/5, f = 210.45707456411003
# Optimization restart 5/5, f = 210.45707479136271
# Optimization restart 1/10, f = -31.162160337148563
# Optimization restart 2/10, f = -31.202887577525495
# Optimization restart 3/10, f = -27.72109744647512
# Optimization restart 4/10, f = -28.347131311661286
# Optimization restart 5/10, f = -31.162185502082977
# Optimization restart 6/10, f = -35.11087339378901
# Optimization restart 7/10, f = -34.73605328697093
# Optimization restart 8/10, f = -25.949329825085407
# Optimization restart 9/10, f = -28.176598799539228
# Optimization restart 10/10, f = -26.802582748975993
# 0.030301784962479515
# Optimization restart 1/5, f = 218.84475161547942
# Optimization restart 2/5, f = 218.84475166505575
# Optimization restart 3/5, f = 218.84475161546476
# Optimization restart 4/5, f = 218.84475161612994
# Optimization restart 5/5, f = 218.84475161547098
# Optimization restart 1/10, f = -31.162160337148563
# Optimization restart 2/10, f = -33.4726584166351
# Optimization restart 3/10, f = -36.812425896419384
# Optimization restart 4/10, f = -32.30361446117034
# Optimization restart 5/10, f = -34.73598130242815
# Optimization restart 6/10, f = -20.578886611564975
# Optimization restart 7/10, f = -33.78655954031636
# Optimization restart 8/10, f = -28.722679955804303
# Optimization restart 9/10, f = -34.58754152861341
# Optimization restart 10/10, f = -31.651300119013023
# 0.02276753820152199
# Optimization restart 1/5, f = 216.04002090532796
# Optimization restart 2/5, f = 216.0400209058413
# Optimization restart 3/5, f = 216.04002090561528
# Optimization restart 4/5, f = 216.04002090477584
# Optimization restart 5/5, f = 216.04002090492608
# Optimization restart 1/10, f = -31.162160337148563
# Optimization restart 2/10, f = -27.855473616501556
# Optimization restart 3/10, f = -25.466827149878775
# Optimization restart 4/10, f = -28.18357985273566
# Optimization restart 5/10, f = -30.26770442316193
# Optimization restart 6/10, f = -34.44844975812879
# Optimization restart 7/10, f = -27.274459770586745
# Optimization restart 8/10, f = -28.011819230354256
# Optimization restart 9/10, f = -34.58692766879727
# Optimization restart 10/10, f = -29.876215855362986
# 0.013799426499585718
# Optimization restart 1/5, f = 216.15244532315106
# Optimization restart 2/5, f = 216.1524455066583
# Optimization restart 3/5, f = 216.15244532301836
# Optimization restart 4/5, f = 216.15244532323652
# Optimization restart 5/5, f = 216.15244532300602
# Optimization restart 1/10, f = -31.162160337148563
# Optimization restart 2/10, f = -28.722626936268846
# Optimization restart 3/10, f = -34.78428892824426
# Optimization restart 4/10, f = -35.381937722927276
# Optimization restart 5/10, f = -27.177814226626836
# Optimization restart 6/10, f = -34.60192678477115
# Optimization restart 7/10, f = -30.64634434677381
# Optimization restart 8/10, f = -30.289978420975864
# Optimization restart 9/10, f = -31.161981277635675
# Optimization restart 10/10, f = -30.187791087097423
# 0.006896312432749624

# %%
up = m.reshape(-1) + 2.0*np.sqrt(v.reshape(-1))
dwn = m.reshape(-1) - 2.0*np.sqrt(v.reshape(-1))
plt.fill_between(x, up, dwn, alpha=0.5)
plt.plot(x, m, label="Mean")
plt.plot(x, y, 'o', label="Noisy Data")
plt.legend()

# %%
plt.plot(x, x, label="Input Variance")
plt.plot(x, 2.0*np.sqrt(v), label="Estimated Variance by GP")
plt.ylabel("Uncertanity estimate")
plt.legend()

# %% [markdown]
# ## Things to do
#
# * I am not 100 percent on the optimization being done for the third GP. May be we can use the same hyperparamters from GP1 for the RBF kernel. Kinda makes sense, will confirm its performance once I implement it.

# %% [markdown]
# ### Transfering hyperparameters across different kernels

# %%
# Out:
# 18.038551864047378

# %%
# Out:
# 0.3236462458020566

# %%
# Out:
# 21.36490657739845

# %%
# Out:
# 0.3225687514413171
